# %%
# !pip install matplotlib imageio
# Out:
# Requirement already satisfied: matplotlib in c:\users\hjbec\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: imageio in c:\users\hjbec\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hjbec\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hjbec\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
import imageio

# Generate sample data
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create a figure and axis
fig, ax = plt.subplots()
line, = ax.plot(x, y)

# Animation function
def animate(i):
    line.set_ydata(np.sin(x + i / 10.0))  # Update the data
    return line,

# Create the animation
ani = animation.FuncAnimation(fig, animate, frames=100, interval=50, blit=True)

# Save the animation as a GIF
ani.save('sine_wave.gif', writer='pillow', fps=20)
plt.show()

# %%
# !pip install plotly kaleido
# Out:
# Requirement already satisfied: plotly in c:\users\hjbec\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: kaleido in c:\users\hjbec\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hjbec\anaconda3\lib\site-packages (from plotly) (8.2.2)
